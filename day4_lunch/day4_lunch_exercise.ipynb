# %% [markdown]
# # Day4 lunch exercise

# %%
import pandas as pd

# %% [markdown]
# ### Load and parse data

# %%
df_gtf = pd.read_csv('BDGP6.Ensembl.81.gtf', sep = '\t', header = None, skiprows = 5)
df_gtf.columns = ['Chr', 'Src', 'Feature', 'Start', 'End', 'Score', 'Strand', 'Frame', 'Attributes']
df_gtf
# Out:
#                     Chr      Src     Feature   Start      End Score Strand  \
# 0                    3R  FlyBase        gene  722370   722621     .      -
# 1                    3R  FlyBase  transcript  722370   722621     .      -
# 2                    3R  FlyBase        exon  722370   722621     .      -
# 3                    3R  FlyBase        gene  835381  2503907     .      +
# 4                    3R  FlyBase  transcript  835381  2503907     .      +
# ...                 ...      ...         ...     ...      ...   ...    ...
# 538334  211000022279342  FlyBase  transcript       1      530     .      +
# 538335  211000022279342  FlyBase        exon       1      530     .      +
# 538336  211000022279132  FlyBase        gene       1     1005     .      +
# 538337  211000022279132  FlyBase  transcript       1     1005     .      +
# 538338  211000022279132  FlyBase        exon       1     1005     .      +
#
#        Frame                                         Attributes
# 0          .  gene_id "FBgn0085804"; gene_version "1"; gene_...
# 1          .  gene_id "FBgn0085804"; gene_version "1"; trans...
# 2          .  gene_id "FBgn0085804"; gene_version "1"; trans...
# 3          .  gene_id "FBgn0267431"; gene_version "1"; gene_...
# 4          .  gene_id "FBgn0267431"; gene_version "1"; trans...
# ...      ...                                                ...
# 538334     .  gene_id "FBgn0085772"; gene_version "1"; trans...
# 538335     .  gene_id "FBgn0085772"; gene_version "1"; trans...
# 538336     .  gene_id "FBgn0085825"; gene_version "1"; gene_...
# 538337     .  gene_id "FBgn0085825"; gene_version "1"; trans...
# 538338     .  gene_id "FBgn0085825"; gene_version "1"; trans...
#
# [538339 rows x 9 columns]

# %% [markdown]
# ## Q1. Search for the nearest protein coding gene by binary search

# %%
select = (df_gtf.loc[:, 'Chr'] == '3R') & (df_gtf.loc[:, 'Attributes'].str.contains('gene_biotype \"protein_coding\"'))
df_gtf_coding = df_gtf.loc[select]
df_gtf_coding
# Out:
#        Chr      Src      Feature     Start       End Score Strand Frame  \
# 3       3R  FlyBase         gene    835381   2503907     .      +     .
# 4       3R  FlyBase   transcript    835381   2503907     .      +     .
# 5       3R  FlyBase         exon    835381    835491     .      +     .
# 6       3R  FlyBase          CDS    835381    835491     .      +     0
# 7       3R  FlyBase  start_codon    835381    835383     .      +     0
# ...     ..      ...          ...       ...       ...   ...    ...   ...
# 124783  3R  FlyBase         exon  32057016  32059145     .      -     .
# 124784  3R  FlyBase          CDS  32057325  32059145     .      -     0
# 124785  3R  FlyBase   stop_codon  32057322  32057324     .      -     0
# 124786  3R  FlyBase          UTR  32067997  32068441     .      -     .
# 124787  3R  FlyBase          UTR  32057016  32057321     .      -     .
#
#                                                Attributes
# 3       gene_id "FBgn0267431"; gene_version "1"; gene_...
# 4       gene_id "FBgn0267431"; gene_version "1"; trans...
# 5       gene_id "FBgn0267431"; gene_version "1"; trans...
# 6       gene_id "FBgn0267431"; gene_version "1"; trans...
# 7       gene_id "FBgn0267431"; gene_version "1"; trans...
# ...                                                   ...
# 124783  gene_id "FBgn0002645"; gene_version "1"; trans...
# 124784  gene_id "FBgn0002645"; gene_version "1"; trans...
# 124785  gene_id "FBgn0002645"; gene_version "1"; trans...
# 124786  gene_id "FBgn0002645"; gene_version "1"; trans...
# 124787  gene_id "FBgn0002645"; gene_version "1"; trans...
#
# [121807 rows x 9 columns]

# %%
def get_genename(nrow, df):
    '''Retrieve gene name from a gtf-generated data frame.'''
    gname = df.iloc[nrow, 8].rstrip().split(sep = 'gene_name \"')[1].rstrip().split('\"')[0]
    return gname

# %%
pos = 21378950

# %% [markdown]
# ### Binary search

# %%
mid = df_gtf_coding.shape[0] // 2
upper = df_gtf_coding.shape[0] - 1
lower = 0
start = df_gtf_coding.iloc[mid, 3]
end = df_gtf_coding.iloc[mid, 4]

# %%
time = 0
while (upper - lower) > 1:
    if start > pos:
        upper = mid
        mid = (upper + lower) // 2
    elif end < pos:
        lower = mid
        mid = (upper + lower) // 2
    else:
        upper = lower
    start = df_gtf_coding.iloc[mid, 3]
    end = df_gtf_coding.iloc[mid, 4]
    time += 1
    print(df_gtf_coding.iloc[upper, 3], 
          df_gtf_coding.iloc[mid, 3], 
          df_gtf_coding.iloc[lower, 3])        #Keep tracing the search progress.
print(get_genename(upper, df_gtf_coding), 
         get_genename(mid, df_gtf_coding), 
         get_genename(lower, df_gtf_coding))
print(time)
# Out:
# 32057016 24668146 18180685
# 24668146 21740105 18180685
# 21740105 20048627 18180685
# 21740105 20865916 20048627
# 21740105 21178278 20865916
# 21740105 21355692 21178278
# 21740105 21524188 21355692
# 21524188 21381828 21355692
# 21381828 21366974 21355692
# 21381828 21367910 21366974
# 21381828 21372142 21367910
# 21381828 21373079 21372142
# 21381828 21379247 21373079
# 21379247 21370918 21373079
# 21379247 21378977 21370918
# 21378977 21378977 21370918
# 21378977 21370918 21370918
# tin pre-mod(mdg4)-N pre-mod(mdg4)-N
# 17

# %%
def dist(nrow, df, pos):
    '''When overlapping, the distance is set to 0. In other cases, the distance is the minimum of
    the distances from start position to query site, and end point to query site.'''
    if (df.iloc[nrow, 3] - pos) * (df.iloc[nrow, 4] - pos) <= 0:
        return 0
    dist = min(abs(df.iloc[nrow, 3] - pos), abs(df.iloc[nrow, 4] - pos))
    return dist

# %%
distance_upper = dist(upper, df_gtf_coding, pos)
distance_lower = dist(lower, df_gtf_coding, pos)

# %%
if distance_upper > distance_lower:
    print(get_genename(lower, df_gtf_coding), distance_lower)
else:
    print(get_genename(upper, df_gtf_coding), distance_upper)
# Out:
# tin 27

# %% [markdown]
# ### Therefore the protein coding gene nearest to 3R: 21378950 is *tin* and the linear distance is 27 bp.

# %% [markdown]
# ## Adv. Q2. Find 20 nearest genes to 3R: 21378950

# %%
nearest_genes_coding=[]
line_up, line_low = upper, upper
nearest_genes_coding.append(get_genename(line_up, df_gtf_coding))
ngenes = len(nearest_genes_coding)
distance = dist(line_up, df_gtf_coding, pos)

while ngenes < 21:
    line_up += 1
    line_low -= 1
    if get_genename(line_up, df_gtf_coding) not in nearest_genes_coding:
        nearest_genes_coding.append(get_genename(line_up, df_gtf_coding))
        ngenes += 1
        if dist(line_up, df_gtf_coding, pos) < distance:   #Make sure that the last gene in nearest_genes_coding is always the furthest to the site of interests.
            nearest_genes_coding[-1], nearest_genes_coding[-2] = nearest_genes_coding[-2], nearest_genes_coding[-1]
        else:
            distance = dist(line_up, df_gtf_coding, pos)
    if get_genename(line_low, df_gtf_coding) not in nearest_genes_coding:
        nearest_genes_coding.append(get_genename(line_low, df_gtf_coding))
        ngenes += 1
        if dist(line_low, df_gtf_coding, pos) < distance:
            nearest_genes_coding[-1], nearest_genes_coding[-2] = nearest_genes_coding[-2], nearest_genes_coding[-1]
        else:
            distance = dist(line_low, df_gtf_coding, pos)

print(nearest_genes_coding)  #In the order that the linear distance to the position of interest gradually increases.
# Out:
# ['tin', 'pre-mod(mdg4)-N', 'pre-mod(mdg4)-AA', 'bap', 'pre-mod(mdg4)-O', 'pre-mod(mdg4)-V', 'CG6475', 'pre-mod(mdg4)-AD', 'pre-mod(mdg4)-X', 'CG7907', 'CheB93a', 'pre-mod(mdg4)-W', 'CheB93b', 'pre-mod(mdg4)-Y', 'pre-mod(mdg4)-U', 'pre-mod(mdg4)-AE', 'lbl', 'lbe', 'pre-mod(mdg4)-AB', 'pre-mod(mdg4)-C', 'CG7922']

# %% [markdown]
# ## Adv. Q3. Find the nearest gene without the limitation in gene type

# %%
select = (df_gtf.loc[:, 'Chr'] == '3R')
df_gtf_3R = df_gtf[select]
df_gtf_3R
# Out:
#        Chr      Src     Feature     Start       End Score Strand Frame  \
# 0       3R  FlyBase        gene    722370    722621     .      -     .
# 1       3R  FlyBase  transcript    722370    722621     .      -     .
# 2       3R  FlyBase        exon    722370    722621     .      -     .
# 3       3R  FlyBase        gene    835381   2503907     .      +     .
# 4       3R  FlyBase  transcript    835381   2503907     .      +     .
# ...     ..      ...         ...       ...       ...   ...    ...   ...
# 124783  3R  FlyBase        exon  32057016  32059145     .      -     .
# 124784  3R  FlyBase         CDS  32057325  32059145     .      -     0
# 124785  3R  FlyBase  stop_codon  32057322  32057324     .      -     0
# 124786  3R  FlyBase         UTR  32067997  32068441     .      -     .
# 124787  3R  FlyBase         UTR  32057016  32057321     .      -     .
#
#                                                Attributes
# 0       gene_id "FBgn0085804"; gene_version "1"; gene_...
# 1       gene_id "FBgn0085804"; gene_version "1"; trans...
# 2       gene_id "FBgn0085804"; gene_version "1"; trans...
# 3       gene_id "FBgn0267431"; gene_version "1"; gene_...
# 4       gene_id "FBgn0267431"; gene_version "1"; trans...
# ...                                                   ...
# 124783  gene_id "FBgn0002645"; gene_version "1"; trans...
# 124784  gene_id "FBgn0002645"; gene_version "1"; trans...
# 124785  gene_id "FBgn0002645"; gene_version "1"; trans...
# 124786  gene_id "FBgn0002645"; gene_version "1"; trans...
# 124787  gene_id "FBgn0002645"; gene_version "1"; trans...
#
# [124788 rows x 9 columns]

# %% [markdown]
# ### Binary search based on start position

# %%
mid = df_gtf_3R.shape[0] // 2
upper = df_gtf_3R.shape[0] - 1
lower = 0
start = df_gtf_3R.iloc[mid, 3]
end = df_gtf_3R.iloc[mid, 4]

# %%
time = 0
while (upper - lower) > 1:
    if start > pos:
        upper = mid
        mid = (upper + lower) // 2
    elif end < pos:
        lower = mid
        mid = (upper + lower) // 2
    else:
        upper = lower
    start = df_gtf_3R.iloc[mid, 3]
    end = df_gtf_3R.iloc[mid, 4]
    time += 1
    print(df_gtf_3R.iloc[upper, 3],
          df_gtf_3R.iloc[mid, 3],
          df_gtf_3R.iloc[lower, 3])     #Keep tracing search progress.
print(get_genename(upper, df_gtf_3R), 
         get_genename(mid, df_gtf_3R), 
         get_genename(lower, df_gtf_3R))
print(time)
# Out:
# 32057016 24705797 18177094
# 24705797 21666253 18177094
# 21666253 20042935 18177094
# 21666253 20844627 20042935
# 21666253 21154927 20844627
# 21666253 21354445 21154927
# 21666253 21499986 21354445
# 21499986 21366974 21354445
# 21499986 21404098 21366974
# 21404098 21373079 21366974
# 21404098 21399723 21373079
# 21399723 21381828 21373079
# 21381828 21379247 21373079
# 21379247 21370918 21373079
# 21379247 21378977 21370918
# 21378977 21378977 21370918
# 21378977 21370918 21370918
# tin pre-mod(mdg4)-N pre-mod(mdg4)-N
# 17

# %% [markdown]
# ### The results are the same no matter whether there is a limitation in gene type.

# %% [markdown]
# ## Adv. Q4. Find nearest genes at sites in a given list

# %%
df_chr = dict()
for chromosome in df_gtf.loc[:, 'Chr'].unique():
    df_chr[chromosome] = df_gtf.loc[df_gtf.loc[:, 'Chr'] == chromosome]
df_chr
# Out:
# {'3R':        Chr      Src     Feature     Start       End Score Strand Frame  \
#  0       3R  FlyBase        gene    722370    722621     .      -     .
#  1       3R  FlyBase  transcript    722370    722621     .      -     .
#  2       3R  FlyBase        exon    722370    722621     .      -     .
#  3       3R  FlyBase        gene    835381   2503907     .      +     .
#  4       3R  FlyBase  transcript    835381   2503907     .      +     .
#  ...     ..      ...         ...       ...       ...   ...    ...   ...
#  124783  3R  FlyBase        exon  32057016  32059145     .      -     .
#  124784  3R  FlyBase         CDS  32057325  32059145     .      -     0
#  124785  3R  FlyBase  stop_codon  32057322  32057324     .      -     0
#  124786  3R  FlyBase         UTR  32067997  32068441     .      -     .
#  124787  3R  FlyBase         UTR  32057016  32057321     .      -     .
#
#                                                 Attributes
#  0       gene_id "FBgn0085804"; gene_version "1"; gene_...
#  1       gene_id "FBgn0085804"; gene_version "1"; trans...
#  2       gene_id "FBgn0085804"; gene_version "1"; trans...
#  3       gene_id "FBgn0267431"; gene_version "1"; gene_...
#  4       gene_id "FBgn0267431"; gene_version "1"; trans...
#  ...                                                   ...
#  124783  gene_id "FBgn0002645"; gene_version "1"; trans...
#  124784  gene_id "FBgn0002645"; gene_version "1"; trans...
#  124785  gene_id "FBgn0002645"; gene_version "1"; trans...
#  124786  gene_id "FBgn0002645"; gene_version "1"; trans...
#  124787  gene_id "FBgn0002645"; gene_version "1"; trans...
#
#  [124788 rows x 9 columns],
#  '3L':        Chr      Src     Feature     Start       End Score Strand Frame  \
#  124788  3L  FlyBase        gene     22428     26308     .      +     .
#  124789  3L  FlyBase  transcript     22428     26308     .      +     .
#  124790  3L  FlyBase        exon     22428     22482     .      +     .
#  124791  3L  FlyBase        exon     22544     24696     .      +     .
#  124792  3L  FlyBase         CDS     24193     24696     .      +     0
#  ...     ..      ...         ...       ...       ...   ...    ...   ...
#  225528  3L  FlyBase        exon  28011343  28011717     .      -     .
#  225529  3L  FlyBase         CDS  28011713  28011717     .      -     2
#  225530  3L  FlyBase  stop_codon  28011710  28011712     .      -     0
#  225531  3L  FlyBase         UTR  28012552  28012599     .      -     .
#  225532  3L  FlyBase         UTR  28011343  28011709     .      -     .
#
#                                                 Attributes
#  124788  gene_id "FBgn0052475"; gene_version "1"; gene_...
#  124789  gene_id "FBgn0052475"; gene_version "1"; trans...
#  124790  gene_id "FBgn0052475"; gene_version "1"; trans...
#  124791  gene_id "FBgn0052475"; gene_version "1"; trans...
#  124792  gene_id "FBgn0052475"; gene_version "1"; trans...
#  ...                                                   ...
#  225528  gene_id "FBgn0039959"; gene_version "1"; trans...
#  225529  gene_id "FBgn0039959"; gene_version "1"; trans...
#  225530  gene_id "FBgn0039959"; gene_version "1"; trans...
#  225531  gene_id "FBgn0039959"; gene_version "1"; trans...
#  225532  gene_id "FBgn0039959"; gene_version "1"; trans...
#
#  [100745 rows x 9 columns],
#  '2R':        Chr      Src      Feature     Start       End Score Strand Frame  \
#  225533  2R  FlyBase         gene    432219    705848     .      +     .
#  225534  2R  FlyBase   transcript    432219    705848     .      +     .
#  225535  2R  FlyBase         exon    432219    432460     .      +     .
#  225536  2R  FlyBase          CDS    432340    432460     .      +     0
#  225537  2R  FlyBase  start_codon    432340    432342     .      +     0
#  ...     ..      ...          ...       ...       ...   ...    ...   ...
#  335636  2R  FlyBase         exon  25254128  25254535     .      +     .
#  335637  2R  FlyBase          CDS  25254128  25254474     .      +     2
#  335638  2R  FlyBase   stop_codon  25254475  25254477     .      +     0
#  335639  2R  FlyBase          UTR  25253314  25253438     .      +     .
#  335640  2R  FlyBase          UTR  25254478  25254535     .      +     .
#
#                                                 Attributes
#  225533  gene_id "FBgn0267428"; gene_version "1"; gene_...
#  225534  gene_id "FBgn0267428"; gene_version "1"; trans...
#  225535  gene_id "FBgn0267428"; gene_version "1"; trans...
#  225536  gene_id "FBgn0267428"; gene_version "1"; trans...
#  225537  gene_id "FBgn0267428"; gene_version "1"; trans...
#  ...                                                   ...
#  335636  gene_id "FBgn0050428"; gene_version "1"; trans...
#  335637  gene_id "FBgn0050428"; gene_version "1"; trans...
#  335638  gene_id "FBgn0050428"; gene_version "1"; trans...
#  335639  gene_id "FBgn0050428"; gene_version "1"; trans...
#  335640  gene_id "FBgn0050428"; gene_version "1"; trans...
#
#  [110108 rows x 9 columns],
#  'X':        Chr      Src     Feature     Start       End Score Strand Frame  \
#  335641   X  FlyBase        gene    122493    122706     .      +     .
#  335642   X  FlyBase  transcript    122493    122706     .      +     .
#  335643   X  FlyBase        exon    122493    122706     .      +     .
#  335644   X  FlyBase        gene    124370    126714     .      -     .
#  335645   X  FlyBase  transcript    124370    126714     .      -     .
#  ...     ..      ...         ...       ...       ...   ...    ...   ...
#  432829   X  FlyBase  transcript  23291549  23291671     .      +     .
#  432830   X  FlyBase        exon  23291549  23291671     .      +     .
#  432831   X  FlyBase        gene  23291700  23291729     .      +     .
#  432832   X  FlyBase  transcript  23291700  23291729     .      +     .
#  432833   X  FlyBase        exon  23291700  23291729     .      +     .
#
#                                                 Attributes
#  335641  gene_id "FBgn0058469"; gene_version "1"; gene_...
#  335642  gene_id "FBgn0058469"; gene_version "1"; trans...
#  335643  gene_id "FBgn0058469"; gene_version "1"; trans...
#  335644  gene_id "FBgn0025837"; gene_version "1"; gene_...
#  335645  gene_id "FBgn0025837"; gene_version "1"; trans...
#  ...                                                   ...
#  432829  gene_id "FBgn0267523"; gene_version "1"; trans...
#  432830  gene_id "FBgn0267523"; gene_version "1"; trans...
#  432831  gene_id "FBgn0267524"; gene_version "1"; gene_...
#  432832  gene_id "FBgn0267524"; gene_version "1"; trans...
#  432833  gene_id "FBgn0267524"; gene_version "1"; trans...
#
#  [97193 rows x 9 columns],
#  '2L':        Chr      Src      Feature     Start       End Score Strand Frame  \
#  432834  2L  FlyBase         gene      7529      9484     .      +     .
#  432835  2L  FlyBase   transcript      7529      9484     .      +     .
#  432836  2L  FlyBase         exon      7529      8116     .      +     .
#  432837  2L  FlyBase          CDS      7680      8116     .      +     0
#  432838  2L  FlyBase  start_codon      7680      7682     .      +     0
#  ...     ..      ...          ...       ...       ...   ...    ...   ...
#  529569  2L  FlyBase         exon  23323955  23324192     .      -     .
#  529570  2L  FlyBase         exon  23320508  23320671     .      -     .
#  529571  2L  FlyBase         gene  23415916  23416153     .      +     .
#  529572  2L  FlyBase   transcript  23415916  23416153     .      +     .
#  529573  2L  FlyBase         exon  23415916  23416153     .      +     .
#
#                                                 Attributes
#  432834  gene_id "FBgn0031208"; gene_version "1"; gene_...
#  432835  gene_id "FBgn0031208"; gene_version "1"; trans...
#  432836  gene_id "FBgn0031208"; gene_version "1"; trans...
#  432837  gene_id "FBgn0031208"; gene_version "1"; trans...
#  432838  gene_id "FBgn0031208"; gene_version "1"; trans...
#  ...                                                   ...
#  529569  gene_id "FBgn0260435"; gene_version "1"; trans...
#  529570  gene_id "FBgn0260435"; gene_version "1"; trans...
#  529571  gene_id "FBgn0085664"; gene_version "1"; gene_...
#  529572  gene_id "FBgn0085664"; gene_version "1"; trans...
#  529573  gene_id "FBgn0085664"; gene_version "1"; trans...
#
#  [96740 rows x 9 columns],
#  'Y':        Chr      Src      Feature    Start      End Score Strand Frame  \
#  529574   Y  FlyBase         gene     9833    10786     .      +     .
#  529575   Y  FlyBase   transcript     9833    10786     .      +     .
#  529576   Y  FlyBase         exon     9833    10786     .      +     .
#  529577   Y  FlyBase          CDS     9833    10783     .      +     0
#  529578   Y  FlyBase  start_codon     9833     9835     .      +     0
#  ...     ..      ...          ...      ...      ...   ...    ...   ...
#  530073   Y  FlyBase         exon  3665092  3666483     .      +     .
#  530074   Y  FlyBase          CDS  3665092  3666483     .      +     0
#  530075   Y  FlyBase         exon  3666584  3666928     .      +     .
#  530076   Y  FlyBase          CDS  3666584  3666925     .      +     0
#  530077   Y  FlyBase   stop_codon  3666926  3666928     .      +     0
#
#                                                 Attributes
#  529574  gene_id "FBgn0261399"; gene_version "1"; gene_...
#  529575  gene_id "FBgn0261399"; gene_version "1"; trans...
#  529576  gene_id "FBgn0261399"; gene_version "1"; trans...
#  529577  gene_id "FBgn0261399"; gene_version "1"; trans...
#  529578  gene_id "FBgn0261399"; gene_version "1"; trans...
#  ...                                                   ...
#  530073  gene_id "FBgn0267592"; gene_version "1"; trans...
#  530074  gene_id "FBgn0267592"; gene_version "1"; trans...
#  530075  gene_id "FBgn0267592"; gene_version "1"; trans...
#  530076  gene_id "FBgn0267592"; gene_version "1"; trans...
#  530077  gene_id "FBgn0267592"; gene_version "1"; trans...
#
#  [504 rows x 9 columns],
#  '4':        Chr      Src      Feature    Start      End Score Strand Frame  \
#  530078   4  FlyBase         gene      879     5039     .      +     .
#  530079   4  FlyBase   transcript      879     5039     .      +     .
#  530080   4  FlyBase         exon      879     1079     .      +     .
#  530081   4  FlyBase          CDS      930     1079     .      +     0
#  530082   4  FlyBase  start_codon      930      932     .      +     0
#  ...     ..      ...          ...      ...      ...   ...    ...   ...
#  537917   4  FlyBase          CDS  1270925  1271126     .      +     1
#  537918   4  FlyBase   stop_codon  1271127  1271129     .      +     0
#  537919   4  FlyBase          UTR  1231883  1232190     .      +     .
#  537920   4  FlyBase          UTR  1233129  1233169     .      +     .
#  537921   4  FlyBase          UTR  1271130  1271759     .      +     .
#
#                                                 Attributes
#  530078  gene_id "FBgn0267363"; gene_version "1"; gene_...
#  530079  gene_id "FBgn0267363"; gene_version "1"; trans...
#  530080  gene_id "FBgn0267363"; gene_version "1"; trans...
#  530081  gene_id "FBgn0267363"; gene_version "1"; trans...
#  530082  gene_id "FBgn0267363"; gene_version "1"; trans...
#  ...                                                   ...
#  537917  gene_id "FBgn0053653"; gene_version "1"; trans...
#  537918  gene_id "FBgn0053653"; gene_version "1"; trans...
#  537919  gene_id "FBgn0053653"; gene_version "1"; trans...
#  537920  gene_id "FBgn0053653"; gene_version "1"; trans...
#  537921  gene_id "FBgn0053653"; gene_version "1"; trans...
#
#  [7844 rows x 9 columns],
#  'Unmapped_Scaffold_8':                         Chr      Src      Feature  Start    End Score Strand  \
#  537922  Unmapped_Scaffold_8  FlyBase         gene   3093   3576     .      -
#  537923  Unmapped_Scaffold_8  FlyBase   transcript   3093   3576     .      -
#  537924  Unmapped_Scaffold_8  FlyBase         exon   3244   3576     .      -
#  537925  Unmapped_Scaffold_8  FlyBase          CDS   3244   3576     .      -
#  537926  Unmapped_Scaffold_8  FlyBase  start_codon   3574   3576     .      -
#  537927  Unmapped_Scaffold_8  FlyBase         exon   3093   3185     .      -
#  537928  Unmapped_Scaffold_8  FlyBase          CDS   3096   3185     .      -
#  537929  Unmapped_Scaffold_8  FlyBase   stop_codon   3093   3095     .      -
#  537930  Unmapped_Scaffold_8  FlyBase         gene  53442  85529     .      +
#  537931  Unmapped_Scaffold_8  FlyBase   transcript  53442  85529     .      +
#  537932  Unmapped_Scaffold_8  FlyBase         exon  53442  53542     .      +
#  537933  Unmapped_Scaffold_8  FlyBase         exon  56891  57267     .      +
#  537934  Unmapped_Scaffold_8  FlyBase          CDS  56945  57267     .      +
#  537935  Unmapped_Scaffold_8  FlyBase  start_codon  56945  56947     .      +
#  537936  Unmapped_Scaffold_8  FlyBase         exon  57320  57604     .      +
#  537937  Unmapped_Scaffold_8  FlyBase          CDS  57320  57604     .      +
#  537938  Unmapped_Scaffold_8  FlyBase         exon  57659  57923     .      +
#  537939  Unmapped_Scaffold_8  FlyBase          CDS  57659  57923     .      +
#  537940  Unmapped_Scaffold_8  FlyBase         exon  83719  83841     .      +
#  537941  Unmapped_Scaffold_8  FlyBase          CDS  83719  83841     .      +
#  537942  Unmapped_Scaffold_8  FlyBase         exon  83902  85529     .      +
#  537943  Unmapped_Scaffold_8  FlyBase          CDS  83902  85206     .      +
#  537944  Unmapped_Scaffold_8  FlyBase   stop_codon  85207  85209     .      +
#  537945  Unmapped_Scaffold_8  FlyBase          UTR  53442  53542     .      +
#  537946  Unmapped_Scaffold_8  FlyBase          UTR  56891  56944     .      +
#  537947  Unmapped_Scaffold_8  FlyBase          UTR  85210  85529     .      +
#  537948  Unmapped_Scaffold_8  FlyBase   transcript  56702  85431     .      +
#  537949  Unmapped_Scaffold_8  FlyBase         exon  56702  56827     .      +
#  537950  Unmapped_Scaffold_8  FlyBase         exon  56891  57267     .      +
#  537951  Unmapped_Scaffold_8  FlyBase          CDS  56945  57267     .      +
#  537952  Unmapped_Scaffold_8  FlyBase  start_codon  56945  56947     .      +
#  537953  Unmapped_Scaffold_8  FlyBase         exon  57320  57604     .      +
#  537954  Unmapped_Scaffold_8  FlyBase          CDS  57320  57604     .      +
#  537955  Unmapped_Scaffold_8  FlyBase         exon  57659  57923     .      +
#  537956  Unmapped_Scaffold_8  FlyBase          CDS  57659  57923     .      +
#  537957  Unmapped_Scaffold_8  FlyBase         exon  83719  83841     .      +
#  537958  Unmapped_Scaffold_8  FlyBase          CDS  83719  83841     .      +
#  537959  Unmapped_Scaffold_8  FlyBase         exon  83902  85431     .      +
#  537960  Unmapped_Scaffold_8  FlyBase          CDS  83902  85206     .      +
#  537961  Unmapped_Scaffold_8  FlyBase   stop_codon  85207  85209     .      +
#  537962  Unmapped_Scaffold_8  FlyBase          UTR  56702  56827     .      +
#  537963  Unmapped_Scaffold_8  FlyBase          UTR  56891  56944     .      +
#  537964  Unmapped_Scaffold_8  FlyBase          UTR  85210  85431     .      +
#
#         Frame                                         Attributes
#  537922     .  gene_id "FBgn0261386"; gene_version "1"; gene_...
#  537923     .  gene_id "FBgn0261386"; gene_version "1"; trans...
#  537924     .  gene_id "FBgn0261386"; gene_version "1"; trans...
#  537925     0  gene_id "FBgn0261386"; gene_version "1"; trans...
#  537926     0  gene_id "FBgn0261386"; gene_version "1"; trans...
#  537927     .  gene_id "FBgn0261386"; gene_version "1"; trans...
#  537928     0  gene_id "FBgn0261386"; gene_version "1"; trans...
#  537929     0  gene_id "FBgn0261386"; gene_version "1"; trans...
#  537930     .  gene_id "FBgn0040038"; gene_version "1"; gene_...
#  537931     .  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537932     .  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537933     .  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537934     0  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537935     0  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537936     .  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537937     1  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537938     .  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537939     1  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537940     .  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537941     0  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537942     .  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537943     0  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537944     0  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537945     .  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537946     .  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537947     .  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537948     .  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537949     .  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537950     .  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537951     0  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537952     0  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537953     .  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537954     1  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537955     .  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537956     1  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537957     .  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537958     0  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537959     .  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537960     0  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537961     0  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537962     .  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537963     .  gene_id "FBgn0040038"; gene_version "1"; trans...
#  537964     .  gene_id "FBgn0040038"; gene_version "1"; trans...  ,
#  'rDNA':          Chr      Src     Feature  Start    End Score Strand Frame  \
#  537965  rDNA  FlyBase        gene   4492   5312     .      -     .
#  537966  rDNA  FlyBase  transcript   4492   5312     .      -     .
#  537967  rDNA  FlyBase        exon   4492   5312     .      -     .
#  537968  rDNA  FlyBase        gene  16375  16497     .      +     .
#  537969  rDNA  FlyBase  transcript  16375  16497     .      +     .
#  537970  rDNA  FlyBase        exon  16375  16497     .      +     .
#  537971  rDNA  FlyBase        gene  16526  16555     .      +     .
#  537972  rDNA  FlyBase  transcript  16526  16555     .      +     .
#  537973  rDNA  FlyBase        exon  16526  16555     .      +     .
#  537974  rDNA  FlyBase        gene  16936  22940     .      +     .
#  537975  rDNA  FlyBase  transcript  16936  22940     .      +     .
#  537976  rDNA  FlyBase        exon  16936  19585     .      +     .
#  537977  rDNA  FlyBase        exon  22816  22940     .      +     .
#  537978  rDNA  FlyBase        gene  35941  38740     .      +     .
#  537979  rDNA  FlyBase  transcript  35941  38740     .      +     .
#  537980  rDNA  FlyBase        exon  35941  36403     .      +     .
#  537981  rDNA  FlyBase        exon  37483  38740     .      +     .
#  537982  rDNA  FlyBase        gene  42623  49485     .      +     .
#  537983  rDNA  FlyBase  transcript  42623  49485     .      +     .
#  537984  rDNA  FlyBase        exon  42623  49485     .      +     .
#  537985  rDNA  FlyBase        gene  43484  45478     .      +     .
#  537986  rDNA  FlyBase  transcript  43484  45478     .      +     .
#  537987  rDNA  FlyBase        exon  43484  45478     .      +     .
#  537988  rDNA  FlyBase        gene  46205  46327     .      +     .
#  537989  rDNA  FlyBase  transcript  46205  46327     .      +     .
#  537990  rDNA  FlyBase        exon  46205  46327     .      +     .
#  537991  rDNA  FlyBase        gene  46356  46385     .      +     .
#  537992  rDNA  FlyBase  transcript  46356  46385     .      +     .
#  537993  rDNA  FlyBase        exon  46356  46385     .      +     .
#  537994  rDNA  FlyBase        gene  46771  49485     .      +     .
#  537995  rDNA  FlyBase  transcript  46771  49485     .      +     .
#  537996  rDNA  FlyBase        exon  46771  49485     .      +     .
#  537997  rDNA  FlyBase        gene  55104  59294     .      +     .
#  537998  rDNA  FlyBase  transcript  55104  59294     .      +     .
#  537999  rDNA  FlyBase        exon  55104  59294     .      +     .
#  538000  rDNA  FlyBase        gene  55965  57959     .      +     .
#  538001  rDNA  FlyBase  transcript  55965  57959     .      +     .
#  538002  rDNA  FlyBase        exon  55965  57959     .      +     .
#  538003  rDNA  FlyBase        gene  58654  58776     .      +     .
#  538004  rDNA  FlyBase  transcript  58654  58776     .      +     .
#  538005  rDNA  FlyBase        exon  58654  58776     .      +     .
#  538006  rDNA  FlyBase        gene  58805  58834     .      +     .
#  538007  rDNA  FlyBase  transcript  58805  58834     .      +     .
#  538008  rDNA  FlyBase        exon  58805  58834     .      +     .
#  538009  rDNA  FlyBase        gene  66807  74924     .      +     .
#  538010  rDNA  FlyBase  transcript  66807  74924     .      +     .
#  538011  rDNA  FlyBase        exon  66807  74924     .      +     .
#  538012  rDNA  FlyBase        gene  67668  69662     .      +     .
#  538013  rDNA  FlyBase  transcript  67668  69662     .      +     .
#  538014  rDNA  FlyBase        exon  67668  69662     .      +     .
#  538015  rDNA  FlyBase        gene  70389  70511     .      +     .
#  538016  rDNA  FlyBase  transcript  70389  70511     .      +     .
#  538017  rDNA  FlyBase        exon  70389  70511     .      +     .
#  538018  rDNA  FlyBase        gene  70540  70569     .      +     .
#  538019  rDNA  FlyBase  transcript  70540  70569     .      +     .
#  538020  rDNA  FlyBase        exon  70540  70569     .      +     .
#  538021  rDNA  FlyBase        gene  70955  74924     .      +     .
#  538022  rDNA  FlyBase  transcript  70955  74924     .      +     .
#  538023  rDNA  FlyBase        exon  70955  74924     .      +     .
#
#                                                 Attributes
#  537965  gene_id "FBgn0267508"; gene_version "1"; gene_...
#  537966  gene_id "FBgn0267508"; gene_version "1"; trans...
#  537967  gene_id "FBgn0267508"; gene_version "1"; trans...
#  537968  gene_id "FBgn0267509"; gene_version "1"; gene_...
#  537969  gene_id "FBgn0267509"; gene_version "1"; trans...
#  537970  gene_id "FBgn0267509"; gene_version "1"; trans...
#  537971  gene_id "FBgn0267510"; gene_version "1"; gene_...
#  537972  gene_id "FBgn0267510"; gene_version "1"; trans...
#  537973  gene_id "FBgn0267510"; gene_version "1"; trans...
#  537974  gene_id "FBgn0085753"; gene_version "1"; gene_...
#  537975  gene_id "FBgn0085753"; gene_version "1"; trans...
#  537976  gene_id "FBgn0085753"; gene_version "1"; trans...
#  537977  gene_id "FBgn0085753"; gene_version "1"; trans...
#  537978  gene_id "FBgn0267511"; gene_version "1"; gene_...
#  537979  gene_id "FBgn0267511"; gene_version "1"; trans...
#  537980  gene_id "FBgn0267511"; gene_version "1"; trans...
#  537981  gene_id "FBgn0267511"; gene_version "1"; trans...
#  537982  gene_id "FBgn0267505"; gene_version "1"; gene_...
#  537983  gene_id "FBgn0267505"; gene_version "1"; trans...
#  537984  gene_id "FBgn0267505"; gene_version "1"; trans...
#  537985  gene_id "FBgn0085802"; gene_version "1"; gene_...
#  537986  gene_id "FBgn0085802"; gene_version "1"; trans...
#  537987  gene_id "FBgn0085802"; gene_version "1"; trans...
#  537988  gene_id "FBgn0267512"; gene_version "1"; gene_...
#  537989  gene_id "FBgn0267512"; gene_version "1"; trans...
#  537990  gene_id "FBgn0267512"; gene_version "1"; trans...
#  537991  gene_id "FBgn0267496"; gene_version "1"; gene_...
#  537992  gene_id "FBgn0267496"; gene_version "1"; trans...
#  537993  gene_id "FBgn0267496"; gene_version "1"; trans...
#  537994  gene_id "FBgn0267497"; gene_version "1"; gene_...
#  537995  gene_id "FBgn0267497"; gene_version "1"; trans...
#  537996  gene_id "FBgn0267497"; gene_version "1"; trans...
#  537997  gene_id "FBgn0267506"; gene_version "1"; gene_...
#  537998  gene_id "FBgn0267506"; gene_version "1"; trans...
#  537999  gene_id "FBgn0267506"; gene_version "1"; trans...
#  538000  gene_id "FBgn0267498"; gene_version "1"; gene_...
#  538001  gene_id "FBgn0267498"; gene_version "1"; trans...
#  538002  gene_id "FBgn0267498"; gene_version "1"; trans...
#  538003  gene_id "FBgn0267499"; gene_version "1"; gene_...
#  538004  gene_id "FBgn0267499"; gene_version "1"; trans...
#  538005  gene_id "FBgn0267499"; gene_version "1"; trans...
#  538006  gene_id "FBgn0267500"; gene_version "1"; gene_...
#  538007  gene_id "FBgn0267500"; gene_version "1"; trans...
#  538008  gene_id "FBgn0267500"; gene_version "1"; trans...
#  538009  gene_id "FBgn0267507"; gene_version "1"; gene_...
#  538010  gene_id "FBgn0267507"; gene_version "1"; trans...
#  538011  gene_id "FBgn0267507"; gene_version "1"; trans...
#  538012  gene_id "FBgn0267501"; gene_version "1"; gene_...
#  538013  gene_id "FBgn0267501"; gene_version "1"; trans...
#  538014  gene_id "FBgn0267501"; gene_version "1"; trans...
#  538015  gene_id "FBgn0267502"; gene_version "1"; gene_...
#  538016  gene_id "FBgn0267502"; gene_version "1"; trans...
#  538017  gene_id "FBgn0267502"; gene_version "1"; trans...
#  538018  gene_id "FBgn0267503"; gene_version "1"; gene_...
#  538019  gene_id "FBgn0267503"; gene_version "1"; trans...
#  538020  gene_id "FBgn0267503"; gene_version "1"; trans...
#  538021  gene_id "FBgn0267504"; gene_version "1"; gene_...
#  538022  gene_id "FBgn0267504"; gene_version "1"; trans...
#  538023  gene_id "FBgn0267504"; gene_version "1"; trans...  ,
#  'dmel_mitochondrion_genome':                               Chr      Src     Feature  Start    End Score  \
#  538024  dmel_mitochondrion_genome  FlyBase        gene      1     65     .
#  538025  dmel_mitochondrion_genome  FlyBase  transcript      1     65     .
#  538026  dmel_mitochondrion_genome  FlyBase        exon      1     65     .
#  538027  dmel_mitochondrion_genome  FlyBase        gene     97    165     .
#  538028  dmel_mitochondrion_genome  FlyBase  transcript     97    165     .
#  ...                           ...      ...         ...    ...    ...   ...
#  538165  dmel_mitochondrion_genome  FlyBase  transcript  14058  14130     .
#  538166  dmel_mitochondrion_genome  FlyBase        exon  14058  14130     .
#  538167  dmel_mitochondrion_genome  FlyBase        gene  14131  14916     .
#  538168  dmel_mitochondrion_genome  FlyBase  transcript  14131  14916     .
#  538169  dmel_mitochondrion_genome  FlyBase        exon  14131  14916     .
#
#         Strand Frame                                         Attributes
#  538024      +     .  gene_id "FBgn0013696"; gene_version "1"; gene_...
#  538025      +     .  gene_id "FBgn0013696"; gene_version "1"; trans...
#  538026      +     .  gene_id "FBgn0013696"; gene_version "1"; trans...
#  538027      -     .  gene_id "FBgn0013703"; gene_version "1"; gene_...
#  538028      -     .  gene_id "FBgn0013703"; gene_version "1"; trans...
#  ...       ...   ...                                                ...
#  538165      -     .  gene_id "FBgn0013708"; gene_version "1"; trans...
#  538166      -     .  gene_id "FBgn0013708"; gene_version "1"; trans...
#  538167      -     .  gene_id "FBgn0013688"; gene_version "1"; gene_...
#  538168      -     .  gene_id "FBgn0013688"; gene_version "1"; trans...
#  538169      -     .  gene_id "FBgn0013688"; gene_version "1"; trans...
#
#  [146 rows x 9 columns],
#  '211000022280328':                     Chr      Src      Feature  Start   End Score Strand Frame  \
#  538170  211000022280328  FlyBase         gene   7386  9527     .      -     .
#  538171  211000022280328  FlyBase   transcript   7386  9527     .      -     .
#  538172  211000022280328  FlyBase         exon   9435  9527     .      -     .
#  538173  211000022280328  FlyBase          CDS   9435  9478     .      -     0
#  538174  211000022280328  FlyBase  start_codon   9476  9478     .      -     0
#  538175  211000022280328  FlyBase         exon   9154  9380     .      -     .
#  538176  211000022280328  FlyBase          CDS   9154  9380     .      -     1
#  538177  211000022280328  FlyBase         exon   7582  8551     .      -     .
#  538178  211000022280328  FlyBase          CDS   7582  8551     .      -     2
#  538179  211000022280328  FlyBase         exon   7386  7523     .      -     .
#  538180  211000022280328  FlyBase          CDS   7448  7523     .      -     1
#  538181  211000022280328  FlyBase   stop_codon   7445  7447     .      -     0
#  538182  211000022280328  FlyBase          UTR   9479  9527     .      -     .
#  538183  211000022280328  FlyBase          UTR   7386  7444     .      -     .
#
#                                                 Attributes
#  538170  gene_id "FBgn0085692"; gene_version "1"; gene_...
#  538171  gene_id "FBgn0085692"; gene_version "1"; trans...
#  538172  gene_id "FBgn0085692"; gene_version "1"; trans...
#  538173  gene_id "FBgn0085692"; gene_version "1"; trans...
#  538174  gene_id "FBgn0085692"; gene_version "1"; trans...
#  538175  gene_id "FBgn0085692"; gene_version "1"; trans...
#  538176  gene_id "FBgn0085692"; gene_version "1"; trans...
#  538177  gene_id "FBgn0085692"; gene_version "1"; trans...
#  538178  gene_id "FBgn0085692"; gene_version "1"; trans...
#  538179  gene_id "FBgn0085692"; gene_version "1"; trans...
#  538180  gene_id "FBgn0085692"; gene_version "1"; trans...
#  538181  gene_id "FBgn0085692"; gene_version "1"; trans...
#  538182  gene_id "FBgn0085692"; gene_version "1"; trans...
#  538183  gene_id "FBgn0085692"; gene_version "1"; trans...  ,
#  '211000022278498':                     Chr      Src     Feature  Start    End Score Strand Frame  \
#  538184  211000022278498  FlyBase        gene  13189  13940     .      -     .
#  538185  211000022278498  FlyBase  transcript  13189  13940     .      -     .
#  538186  211000022278498  FlyBase        exon  13189  13940     .      -     .
#
#                                                 Attributes
#  538184  gene_id "FBgn0085828"; gene_version "1"; gene_...
#  538185  gene_id "FBgn0085828"; gene_version "1"; trans...
#  538186  gene_id "FBgn0085828"; gene_version "1"; trans...  ,
#  '211000022278875':                     Chr      Src     Feature  Start   End Score Strand Frame  \
#  538187  211000022278875  FlyBase        gene      1  2099     .      +     .
#  538188  211000022278875  FlyBase  transcript      1  2099     .      +     .
#  538189  211000022278875  FlyBase        exon      1  2099     .      +     .
#
#                                                 Attributes
#  538187  gene_id "FBgn0085816"; gene_version "1"; gene_...
#  538188  gene_id "FBgn0085816"; gene_version "1"; trans...
#  538189  gene_id "FBgn0085816"; gene_version "1"; trans...  ,
#  '211000022279446':                     Chr      Src     Feature  Start   End Score Strand Frame  \
#  538190  211000022279446  FlyBase        gene      1  1266     .      +     .
#  538191  211000022279446  FlyBase  transcript      1  1266     .      +     .
#  538192  211000022279446  FlyBase        exon      1  1266     .      +     .
#
#                                                 Attributes
#  538190  gene_id "FBgn0085817"; gene_version "1"; gene_...
#  538191  gene_id "FBgn0085817"; gene_version "1"; trans...
#  538192  gene_id "FBgn0085817"; gene_version "1"; trans...  ,
#  '211000022278279':                     Chr      Src     Feature  Start    End Score Strand Frame  \
#  538193  211000022278279  FlyBase        gene  11634  12709     .      -     .
#  538194  211000022278279  FlyBase  transcript  11634  12709     .      -     .
#  538195  211000022278279  FlyBase        exon  11634  12709     .      -     .
#
#                                                 Attributes
#  538193  gene_id "FBgn0267594"; gene_version "1"; gene_...
#  538194  gene_id "FBgn0267594"; gene_version "1"; trans...
#  538195  gene_id "FBgn0267594"; gene_version "1"; trans...  ,
#  '211000022279681':                     Chr      Src     Feature  Start   End Score Strand Frame  \
#  538196  211000022279681  FlyBase        gene    401  1054     .      +     .
#  538197  211000022279681  FlyBase  transcript    401  1054     .      +     .
#  538198  211000022279681  FlyBase        exon    401  1054     .      +     .
#
#                                                 Attributes
#  538196  gene_id "FBgn0259837"; gene_version "1"; gene_...
#  538197  gene_id "FBgn0259837"; gene_version "1"; trans...
#  538198  gene_id "FBgn0259837"; gene_version "1"; trans...  ,
#  '211000022280645':                     Chr      Src     Feature  Start  End Score Strand Frame  \
#  538199  211000022280645  FlyBase        gene      1  765     .      +     .
#  538200  211000022280645  FlyBase  transcript      1  765     .      +     .
#  538201  211000022280645  FlyBase        exon      1  765     .      +     .
#
#                                                 Attributes
#  538199  gene_id "FBgn0085777"; gene_version "1"; gene_...
#  538200  gene_id "FBgn0085777"; gene_version "1"; trans...
#  538201  gene_id "FBgn0085777"; gene_version "1"; trans...  ,
#  '211000022280494':                     Chr      Src     Feature  Start   End Score Strand Frame  \
#  538202  211000022280494  FlyBase        gene      1  1443     .      -     .
#  538203  211000022280494  FlyBase  transcript      1  1443     .      -     .
#  538204  211000022280494  FlyBase        exon      1  1443     .      -     .
#  538205  211000022280494  FlyBase        gene   2048  3374     .      -     .
#  538206  211000022280494  FlyBase  transcript   2048  3374     .      -     .
#  538207  211000022280494  FlyBase        exon   2048  3374     .      -     .
#
#                                                 Attributes
#  538202  gene_id "FBgn0259839"; gene_version "1"; gene_...
#  538203  gene_id "FBgn0259839"; gene_version "1"; trans...
#  538204  gene_id "FBgn0259839"; gene_version "1"; trans...
#  538205  gene_id "FBgn0259840"; gene_version "1"; gene_...
#  538206  gene_id "FBgn0259840"; gene_version "1"; trans...
#  538207  gene_id "FBgn0259840"; gene_version "1"; trans...  ,
#  '211000022280703':                     Chr      Src     Feature  Start   End Score Strand Frame  \
#  538208  211000022280703  FlyBase        gene    699  1770     .      +     .
#  538209  211000022280703  FlyBase  transcript    699  1770     .      +     .
#  538210  211000022280703  FlyBase        exon    699  1770     .      +     .
#
#                                                 Attributes
#  538208  gene_id "FBgn0267596"; gene_version "1"; gene_...
#  538209  gene_id "FBgn0267596"; gene_version "1"; trans...
#  538210  gene_id "FBgn0267596"; gene_version "1"; trans...  ,
#  '211000022280481':                     Chr      Src     Feature  Start   End Score Strand Frame  \
#  538211  211000022280481  FlyBase        gene   1230  2419     .      +     .
#  538212  211000022280481  FlyBase  transcript   1230  2419     .      +     .
#  538213  211000022280481  FlyBase        exon   1230  2419     .      +     .
#
#                                                 Attributes
#  538211  gene_id "FBgn0259842"; gene_version "1"; gene_...
#  538212  gene_id "FBgn0259842"; gene_version "1"; trans...
#  538213  gene_id "FBgn0259842"; gene_version "1"; trans...  ,
#  '211000022279188':                     Chr      Src      Feature  Start   End Score Strand Frame  \
#  538214  211000022279188  FlyBase         gene   1449  2180     .      +     .
#  538215  211000022279188  FlyBase   transcript   1449  2180     .      +     .
#  538216  211000022279188  FlyBase         exon   1449  1489     .      +     .
#  538217  211000022279188  FlyBase          CDS   1479  1489     .      +     0
#  538218  211000022279188  FlyBase  start_codon   1479  1481     .      +     0
#  538219  211000022279188  FlyBase         exon   1547  2047     .      +     .
#  538220  211000022279188  FlyBase          CDS   1547  2047     .      +     1
#  538221  211000022279188  FlyBase         exon   2108  2180     .      +     .
#  538222  211000022279188  FlyBase          CDS   2108  2111     .      +     1
#  538223  211000022279188  FlyBase   stop_codon   2112  2114     .      +     0
#  538224  211000022279188  FlyBase          UTR   1449  1478     .      +     .
#  538225  211000022279188  FlyBase          UTR   2115  2180     .      +     .
#
#                                                 Attributes
#  538214  gene_id "FBgn0259817"; gene_version "1"; gene_...
#  538215  gene_id "FBgn0259817"; gene_version "1"; trans...
#  538216  gene_id "FBgn0259817"; gene_version "1"; trans...
#  538217  gene_id "FBgn0259817"; gene_version "1"; trans...
#  538218  gene_id "FBgn0259817"; gene_version "1"; trans...
#  538219  gene_id "FBgn0259817"; gene_version "1"; trans...
#  538220  gene_id "FBgn0259817"; gene_version "1"; trans...
#  538221  gene_id "FBgn0259817"; gene_version "1"; trans...
#  538222  gene_id "FBgn0259817"; gene_version "1"; trans...
#  538223  gene_id "FBgn0259817"; gene_version "1"; trans...
#  538224  gene_id "FBgn0259817"; gene_version "1"; trans...
#  538225  gene_id "FBgn0259817"; gene_version "1"; trans...  ,
#  '211000022278724':                     Chr      Src     Feature  Start   End Score Strand Frame  \
#  538226  211000022278724  FlyBase        gene    930  2904     .      -     .
#  538227  211000022278724  FlyBase  transcript    930  2904     .      -     .
#  538228  211000022278724  FlyBase        exon    930  2904     .      -     .
#
#                                                 Attributes
#  538226  gene_id "FBgn0085805"; gene_version "1"; gene_...
#  538227  gene_id "FBgn0085805"; gene_version "1"; trans...
#  538228  gene_id "FBgn0085805"; gene_version "1"; trans...  ,
#  '211000022278436':                     Chr      Src     Feature  Start   End Score Strand Frame  \
#  538229  211000022278436  FlyBase        gene   1551  2815     .      -     .
#  538230  211000022278436  FlyBase  transcript   1551  2815     .      -     .
#  538231  211000022278436  FlyBase        exon   1551  2815     .      -     .
#
#                                                 Attributes
#  538229  gene_id "FBgn0259849"; gene_version "1"; gene_...
#  538230  gene_id "FBgn0259849"; gene_version "1"; trans...
#  538231  gene_id "FBgn0259849"; gene_version "1"; trans...  ,
#  '211000022278282':                     Chr      Src     Feature  Start   End Score Strand Frame  \
#  538232  211000022278282  FlyBase        gene    518  2511     .      +     .
#  538233  211000022278282  FlyBase  transcript    518  2511     .      +     .
#  538234  211000022278282  FlyBase        exon    518  2511     .      +     .
#
#                                                 Attributes
#  538232  gene_id "FBgn0085807"; gene_version "1"; gene_...
#  538233  gene_id "FBgn0085807"; gene_version "1"; trans...
#  538234  gene_id "FBgn0085807"; gene_version "1"; trans...  ,
#  '211000022278664':                     Chr      Src     Feature  Start   End Score Strand Frame  \
#  538235  211000022278664  FlyBase        gene      1  1088     .      -     .
#  538236  211000022278664  FlyBase  transcript      1  1088     .      -     .
#  538237  211000022278664  FlyBase        exon      1  1088     .      -     .
#
#                                                 Attributes
#  538235  gene_id "FBgn0085755"; gene_version "1"; gene_...
#  538236  gene_id "FBgn0085755"; gene_version "1"; trans...
#  538237  gene_id "FBgn0085755"; gene_version "1"; trans...  ,
#  '211000022280133':                     Chr      Src     Feature  Start   End Score Strand Frame  \
#  538238  211000022280133  FlyBase        gene    220  2161     .      -     .
#  538239  211000022280133  FlyBase  transcript    220  2161     .      -     .
#  538240  211000022280133  FlyBase        exon    220  2161     .      -     .
#
#                                                 Attributes
#  538238  gene_id "FBgn0085808"; gene_version "1"; gene_...
#  538239  gene_id "FBgn0085808"; gene_version "1"; trans...
#  538240  gene_id "FBgn0085808"; gene_version "1"; trans...  ,
#  '211000022278522':                     Chr      Src     Feature  Start   End Score Strand Frame  \
#  538241  211000022278522  FlyBase        gene    390  2086     .      -     .
#  538242  211000022278522  FlyBase  transcript    390  2086     .      -     .
#  538243  211000022278522  FlyBase        exon    390  2086     .      -     .
#
#                                                 Attributes
#  538241  gene_id "FBgn0085744"; gene_version "1"; gene_...
#  538242  gene_id "FBgn0085744"; gene_version "1"; trans...
#  538243  gene_id "FBgn0085744"; gene_version "1"; trans...  ,
#  '211000022278879':                     Chr      Src     Feature  Start  End Score Strand Frame  \
#  538244  211000022278879  FlyBase        gene      1  559     .      +     .
#  538245  211000022278879  FlyBase  transcript      1  559     .      +     .
#  538246  211000022278879  FlyBase        exon      1  559     .      +     .
#
#                                                 Attributes
#  538244  gene_id "FBgn0085760"; gene_version "1"; gene_...
#  538245  gene_id "FBgn0085760"; gene_version "1"; trans...
#  538246  gene_id "FBgn0085760"; gene_version "1"; trans...  ,
#  '211000022278449':                     Chr      Src     Feature  Start   End Score Strand Frame  \
#  538247  211000022278449  FlyBase        gene    528  1635     .      -     .
#  538248  211000022278449  FlyBase  transcript    528  1635     .      -     .
#  538249  211000022278449  FlyBase        exon   1245  1635     .      -     .
#  538250  211000022278449  FlyBase        exon    528  1187     .      -     .
#
#                                                 Attributes
#  538247  gene_id "FBgn0085494"; gene_version "1"; gene_...
#  538248  gene_id "FBgn0085494"; gene_version "1"; trans...
#  538249  gene_id "FBgn0085494"; gene_version "1"; trans...
#  538250  gene_id "FBgn0085494"; gene_version "1"; trans...  ,
#  '211000022280347':                     Chr      Src     Feature  Start  End Score Strand Frame  \
#  538251  211000022280347  FlyBase        gene      7  354     .      -     .
#  538252  211000022280347  FlyBase  transcript      7  354     .      -     .
#  538253  211000022280347  FlyBase        exon      7  354     .      -     .
#
#                                                 Attributes
#  538251  gene_id "FBgn0085540"; gene_version "1"; gene_...
#  538252  gene_id "FBgn0085540"; gene_version "1"; trans...
#  538253  gene_id "FBgn0085540"; gene_version "1"; trans...  ,
#  '211000022278298':                     Chr      Src     Feature  Start   End Score Strand Frame  \
#  538254  211000022278298  FlyBase        gene    648  1614     .      +     .
#  538255  211000022278298  FlyBase  transcript    648  1614     .      +     .
#  538256  211000022278298  FlyBase        exon    648  1614     .      +     .
#
#                                                 Attributes
#  538254  gene_id "FBgn0085746"; gene_version "1"; gene_...
#  538255  gene_id "FBgn0085746"; gene_version "1"; trans...
#  538256  gene_id "FBgn0085746"; gene_version "1"; trans...  ,
#  '211000022278307':                     Chr      Src     Feature  Start  End Score Strand Frame  \
#  538257  211000022278307  FlyBase        gene      1  824     .      -     .
#  538258  211000022278307  FlyBase  transcript      1  824     .      -     .
#  538259  211000022278307  FlyBase        exon      1  824     .      -     .
#
#                                                 Attributes
#  538257  gene_id "FBgn0085751"; gene_version "1"; gene_...
#  538258  gene_id "FBgn0085751"; gene_version "1"; trans...
#  538259  gene_id "FBgn0085751"; gene_version "1"; trans...  ,
#  '211000022279529':                     Chr      Src     Feature  Start  End Score Strand Frame  \
#  538260  211000022279529  FlyBase        gene      1  838     .      +     .
#  538261  211000022279529  FlyBase  transcript      1  838     .      +     .
#  538262  211000022279529  FlyBase        exon      1  838     .      +     .
#
#                                                 Attributes
#  538260  gene_id "FBgn0085773"; gene_version "1"; gene_...
#  538261  gene_id "FBgn0085773"; gene_version "1"; trans...
#  538262  gene_id "FBgn0085773"; gene_version "1"; trans...  ,
#  '211000022280341':                     Chr      Src     Feature  Start  End Score Strand Frame  \
#  538263  211000022280341  FlyBase        gene      1  740     .      -     .
#  538264  211000022280341  FlyBase  transcript      1  740     .      -     .
#  538265  211000022280341  FlyBase        exon      1  740     .      -     .
#
#                                                 Attributes
#  538263  gene_id "FBgn0267595"; gene_version "1"; gene_...
#  538264  gene_id "FBgn0267595"; gene_version "1"; trans...
#  538265  gene_id "FBgn0267595"; gene_version "1"; trans...  ,
#  '211000022279392':                     Chr      Src     Feature  Start   End Score Strand Frame  \
#  538266  211000022279392  FlyBase        gene      1  1356     .      -     .
#  538267  211000022279392  FlyBase  transcript      1  1356     .      -     .
#  538268  211000022279392  FlyBase        exon      1  1356     .      -     .
#
#                                                 Attributes
#  538266  gene_id "FBgn0259864"; gene_version "1"; gene_...
#  538267  gene_id "FBgn0259864"; gene_version "1"; trans...
#  538268  gene_id "FBgn0259864"; gene_version "1"; trans...  ,
#  '211000022278604':                     Chr      Src     Feature  Start  End Score Strand Frame  \
#  538269  211000022278604  FlyBase        gene      1  265     .      +     .
#  538270  211000022278604  FlyBase  transcript      1  265     .      +     .
#  538271  211000022278604  FlyBase        exon      1  265     .      +     .
#
#                                                 Attributes
#  538269  gene_id "FBgn0085752"; gene_version "1"; gene_...
#  538270  gene_id "FBgn0085752"; gene_version "1"; trans...
#  538271  gene_id "FBgn0085752"; gene_version "1"; trans...  ,
#  '211000022279708':                     Chr      Src     Feature  Start   End Score Strand Frame  \
#  538272  211000022279708  FlyBase        gene    608  1275     .      +     .
#  538273  211000022279708  FlyBase  transcript    608  1275     .      +     .
#  538274  211000022279708  FlyBase        exon    608  1275     .      +     .
#
#                                                 Attributes
#  538272  gene_id "FBgn0085795"; gene_version "1"; gene_...
#  538273  gene_id "FBgn0085795"; gene_version "1"; trans...
#  538274  gene_id "FBgn0085795"; gene_version "1"; trans...  ,
#  '211000022279528':                     Chr      Src     Feature  Start  End Score Strand Frame  \
#  538275  211000022279528  FlyBase        gene      2  463     .      +     .
#  538276  211000022279528  FlyBase  transcript      2  463     .      +     .
#  538277  211000022279528  FlyBase        exon      2  463     .      +     .
#
#                                                 Attributes
#  538275  gene_id "FBgn0085827"; gene_version "1"; gene_...
#  538276  gene_id "FBgn0085827"; gene_version "1"; trans...
#  538277  gene_id "FBgn0085827"; gene_version "1"; trans...  ,
#  '211000022279531':                     Chr      Src     Feature  Start   End Score Strand Frame  \
#  538278  211000022279531  FlyBase        gene    626  1200     .      -     .
#  538279  211000022279531  FlyBase  transcript    626  1200     .      -     .
#  538280  211000022279531  FlyBase        exon    626  1200     .      -     .
#
#                                                 Attributes
#  538278  gene_id "FBgn0085822"; gene_version "1"; gene_...
#  538279  gene_id "FBgn0085822"; gene_version "1"; trans...
#  538280  gene_id "FBgn0085822"; gene_version "1"; trans...  ,
#  '211000022279555':                     Chr      Src     Feature  Start   End Score Strand Frame  \
#  538281  211000022279555  FlyBase        gene     51  1080     .      -     .
#  538282  211000022279555  FlyBase  transcript     51  1080     .      -     .
#  538283  211000022279555  FlyBase        exon     51  1080     .      -     .
#
#                                                 Attributes
#  538281  gene_id "FBgn0085803"; gene_version "1"; gene_...
#  538282  gene_id "FBgn0085803"; gene_version "1"; trans...
#  538283  gene_id "FBgn0085803"; gene_version "1"; trans...  ,
#  '211000022278760':                     Chr      Src      Feature  Start  End Score Strand Frame  \
#  538284  211000022278760  FlyBase         gene    562  879     .      -     .
#  538285  211000022278760  FlyBase   transcript    562  879     .      -     .
#  538286  211000022278760  FlyBase         exon    869  879     .      -     .
#  538287  211000022278760  FlyBase          CDS    869  879     .      -     0
#  538288  211000022278760  FlyBase  start_codon    877  879     .      -     0
#  538289  211000022278760  FlyBase         exon    562  814     .      -     .
#  538290  211000022278760  FlyBase          CDS    562  814     .      -     1
#
#                                                 Attributes
#  538284  gene_id "FBgn0085506"; gene_version "1"; gene_...
#  538285  gene_id "FBgn0085506"; gene_version "1"; trans...
#  538286  gene_id "FBgn0085506"; gene_version "1"; trans...
#  538287  gene_id "FBgn0085506"; gene_version "1"; trans...
#  538288  gene_id "FBgn0085506"; gene_version "1"; trans...
#  538289  gene_id "FBgn0085506"; gene_version "1"; trans...
#  538290  gene_id "FBgn0085506"; gene_version "1"; trans...  ,
#  '211000022279222':                     Chr      Src     Feature  Start  End Score Strand Frame  \
#  538291  211000022279222  FlyBase        gene      1  506     .      +     .
#  538292  211000022279222  FlyBase  transcript      1  506     .      +     .
#  538293  211000022279222  FlyBase        exon      1  506     .      +     .
#
#                                                 Attributes
#  538291  gene_id "FBgn0085768"; gene_version "1"; gene_...
#  538292  gene_id "FBgn0085768"; gene_version "1"; trans...
#  538293  gene_id "FBgn0085768"; gene_version "1"; trans...  ,
#  '211000022278750':                     Chr      Src     Feature  Start   End Score Strand Frame  \
#  538294  211000022278750  FlyBase        gene      1  1134     .      +     .
#  538295  211000022278750  FlyBase  transcript      1  1134     .      +     .
#  538296  211000022278750  FlyBase        exon      1  1134     .      +     .
#
#                                                 Attributes
#  538294  gene_id "FBgn0085757"; gene_version "1"; gene_...
#  538295  gene_id "FBgn0085757"; gene_version "1"; trans...
#  538296  gene_id "FBgn0085757"; gene_version "1"; trans...  ,
#  '211000022278877':                     Chr      Src     Feature  Start  End Score Strand Frame  \
#  538297  211000022278877  FlyBase        gene      1  549     .      +     .
#  538298  211000022278877  FlyBase  transcript      1  549     .      +     .
#  538299  211000022278877  FlyBase        exon      1  549     .      +     .
#
#                                                 Attributes
#  538297  gene_id "FBgn0085758"; gene_version "1"; gene_...
#  538298  gene_id "FBgn0085758"; gene_version "1"; trans...
#  538299  gene_id "FBgn0085758"; gene_version "1"; trans...  ,
#  '211000022279055':                     Chr      Src     Feature  Start   End Score Strand Frame  \
#  538300  211000022279055  FlyBase        gene    384  1123     .      +     .
#  538301  211000022279055  FlyBase  transcript    384  1123     .      +     .
#  538302  211000022279055  FlyBase        exon    384  1123     .      +     .
#
#                                                 Attributes
#  538300  gene_id "FBgn0085764"; gene_version "1"; gene_...
#  538301  gene_id "FBgn0085764"; gene_version "1"; trans...
#  538302  gene_id "FBgn0085764"; gene_version "1"; trans...  ,
#  '211000022279165':                     Chr      Src     Feature  Start   End Score Strand Frame  \
#  538303  211000022279165  FlyBase        gene     14  1118     .      -     .
#  538304  211000022279165  FlyBase  transcript     14  1118     .      -     .
#  538305  211000022279165  FlyBase        exon     14  1118     .      -     .
#
#                                                 Attributes
#  538303  gene_id "FBgn0259870"; gene_version "1"; gene_...
#  538304  gene_id "FBgn0259870"; gene_version "1"; trans...
#  538305  gene_id "FBgn0259870"; gene_version "1"; trans...  ,
#  '211000022279108':                     Chr      Src     Feature  Start  End Score Strand Frame  \
#  538306  211000022279108  FlyBase        gene      1  566     .      +     .
#  538307  211000022279108  FlyBase  transcript      1  566     .      +     .
#  538308  211000022279108  FlyBase        exon      1  566     .      +     .
#
#                                                 Attributes
#  538306  gene_id "FBgn0085761"; gene_version "1"; gene_...
#  538307  gene_id "FBgn0085761"; gene_version "1"; trans...
#  538308  gene_id "FBgn0085761"; gene_version "1"; trans...  ,
#  '211000022278309':                     Chr      Src     Feature  Start   End Score Strand Frame  \
#  538309  211000022278309  FlyBase        gene      1  1110     .      +     .
#  538310  211000022278309  FlyBase  transcript      1  1110     .      +     .
#  538311  211000022278309  FlyBase        exon      1  1110     .      +     .
#
#                                                 Attributes
#  538309  gene_id "FBgn0085748"; gene_version "1"; gene_...
#  538310  gene_id "FBgn0085748"; gene_version "1"; trans...
#  538311  gene_id "FBgn0085748"; gene_version "1"; trans...  ,
#  '211000022278603':                     Chr      Src     Feature  Start  End Score Strand Frame  \
#  538312  211000022278603  FlyBase        gene      1  834     .      -     .
#  538313  211000022278603  FlyBase  transcript      1  834     .      -     .
#  538314  211000022278603  FlyBase        exon      1  834     .      -     .
#
#                                                 Attributes
#  538312  gene_id "FBgn0085756"; gene_version "1"; gene_...
#  538313  gene_id "FBgn0085756"; gene_version "1"; trans...
#  538314  gene_id "FBgn0085756"; gene_version "1"; trans...  ,
#  '211000022278880':                     Chr      Src     Feature  Start  End Score Strand Frame  \
#  538315  211000022278880  FlyBase        gene      1  540     .      +     .
#  538316  211000022278880  FlyBase  transcript      1  540     .      +     .
#  538317  211000022278880  FlyBase        exon      1  540     .      +     .
#
#                                                 Attributes
#  538315  gene_id "FBgn0085799"; gene_version "1"; gene_...
#  538316  gene_id "FBgn0085799"; gene_version "1"; trans...
#  538317  gene_id "FBgn0085799"; gene_version "1"; trans...  ,
#  '211000022278878':                     Chr      Src     Feature  Start  End Score Strand Frame  \
#  538318  211000022278878  FlyBase        gene      1  569     .      +     .
#  538319  211000022278878  FlyBase  transcript      1  569     .      +     .
#  538320  211000022278878  FlyBase        exon      1  569     .      +     .
#
#                                                 Attributes
#  538318  gene_id "FBgn0085759"; gene_version "1"; gene_...
#  538319  gene_id "FBgn0085759"; gene_version "1"; trans...
#  538320  gene_id "FBgn0085759"; gene_version "1"; trans...  ,
#  '211000022278985':                     Chr      Src     Feature  Start   End Score Strand Frame  \
#  538321  211000022278985  FlyBase        gene    497  1020     .      -     .
#  538322  211000022278985  FlyBase  transcript    497  1020     .      -     .
#  538323  211000022278985  FlyBase        exon    497  1020     .      -     .
#
#                                                 Attributes
#  538321  gene_id "FBgn0085826"; gene_version "1"; gene_...
#  538322  gene_id "FBgn0085826"; gene_version "1"; trans...
#  538323  gene_id "FBgn0085826"; gene_version "1"; trans...  ,
#  '211000022278158':                     Chr      Src     Feature  Start   End Score Strand Frame  \
#  538324  211000022278158  FlyBase        gene    592  1036     .      +     .
#  538325  211000022278158  FlyBase  transcript    592  1036     .      +     .
#  538326  211000022278158  FlyBase        exon    592  1036     .      +     .
#
#                                                 Attributes
#  538324  gene_id "FBgn0085737"; gene_version "1"; gene_...
#  538325  gene_id "FBgn0085737"; gene_version "1"; trans...
#  538326  gene_id "FBgn0085737"; gene_version "1"; trans...  ,
#  '211000022279264':                     Chr      Src     Feature  Start  End Score Strand Frame  \
#  538327  211000022279264  FlyBase        gene    180  614     .      -     .
#  538328  211000022279264  FlyBase  transcript    180  614     .      -     .
#  538329  211000022279264  FlyBase        exon    180  614     .      -     .
#
#                                                 Attributes
#  538327  gene_id "FBgn0085511"; gene_version "1"; gene_...
#  538328  gene_id "FBgn0085511"; gene_version "1"; trans...
#  538329  gene_id "FBgn0085511"; gene_version "1"; trans...  ,
#  '211000022279134':                     Chr      Src     Feature  Start   End Score Strand Frame  \
#  538330  211000022279134  FlyBase        gene      1  1012     .      +     .
#  538331  211000022279134  FlyBase  transcript      1  1012     .      +     .
#  538332  211000022279134  FlyBase        exon      1  1012     .      +     .
#
#                                                 Attributes
#  538330  gene_id "FBgn0085766"; gene_version "1"; gene_...
#  538331  gene_id "FBgn0085766"; gene_version "1"; trans...
#  538332  gene_id "FBgn0085766"; gene_version "1"; trans...  ,
#  '211000022279342':                     Chr      Src     Feature  Start  End Score Strand Frame  \
#  538333  211000022279342  FlyBase        gene      1  530     .      +     .
#  538334  211000022279342  FlyBase  transcript      1  530     .      +     .
#  538335  211000022279342  FlyBase        exon      1  530     .      +     .
#
#                                                 Attributes
#  538333  gene_id "FBgn0085772"; gene_version "1"; gene_...
#  538334  gene_id "FBgn0085772"; gene_version "1"; trans...
#  538335  gene_id "FBgn0085772"; gene_version "1"; trans...  ,
#  '211000022279132':                     Chr      Src     Feature  Start   End Score Strand Frame  \
#  538336  211000022279132  FlyBase        gene      1  1005     .      +     .
#  538337  211000022279132  FlyBase  transcript      1  1005     .      +     .
#  538338  211000022279132  FlyBase        exon      1  1005     .      +     .
#
#                                                 Attributes
#  538336  gene_id "FBgn0085825"; gene_version "1"; gene_...
#  538337  gene_id "FBgn0085825"; gene_version "1"; trans...
#  538338  gene_id "FBgn0085825"; gene_version "1"; trans...  }

# %%
positions = open('day3_100_positions.txt', 'r')
positions.seek(0, 0)
# Out:
# 0

# %%
for line in positions:
    chromosome, pos = line.rstrip().split()
    pos = int(pos)
    df = df_chr[chromosome]

    mid = df.shape[0] // 2
    upper = df.shape[0] - 1
    lower = 0
    start = df.iloc[mid, 3]
    end = df.iloc[mid, 4]
    time = 0
    while (upper - lower) > 1:
        if start > pos:
            upper = mid
            mid = (upper + lower) // 2
        elif end < pos:
            lower = mid
            mid = (upper + lower) // 2
        else:
            upper = lower
        start = df.iloc[mid, 3]
        end = df.iloc[mid, 4]
        time += 1
    if dist(upper, df, pos) < dist(lower, df, pos):
        print(get_genename(upper, df))
    elif dist(upper, df, pos) > dist(lower, df, pos):
        print(get_genename(lower, df))
    else:
        print(get_genename(upper, df), get_genename(lower, df))
    print(time, '\n')
# Out:
# CG31835
# 17
#
# CR44739
# 17
#
# CG43331
# 17
#
# CG17193
# 17
#
# Snup
# 17
#
# tRNA:CR32173
# 17
#
# Ntf-2 Ntf-2
# 7
#
# RpL14
# 17
#
# Tsc1
# 17
#
# CG33658
# 17
#
# CR45279
# 17
#
# CG10483
# 17
#
# feo
# 17
#
# CG8321 CG8321
# 14
#
# CG33965
# 17
#
# GalNAc-T1
# 17
#
# CG4169
# 17
#
# CG31496
# 17
#
# CG31661
# 17
#
# RpL14
# 17
#
# tRNA:S7:64D
# 17
#
# Catsup
# 17
#
# CR45656
# 17
#
# Kap-alpha1
# 16
#
# eIF4G
# 13
#
# TfAP-2
# 17
#
# CG30177 CG30177
# 15
#
# CG7686
# 16
#
# CG4164
# 17
#
# CR42746
# 17
#
# CG3769 CG3769
# 17
#
# Cyp4d21
# 17
#
# CR43621
# 16
#
# Cha
# 17
#
# CG8031
# 17
#
# CR45405
# 17
#
# bab2
# 17
#
# RhoGAPp190
# 16
#
# CG8974
# 16
#
# Npc2g
# 16
#
# eIF4E-3
# 16
#
# 5SrRNA:CR33442
# 17
#
# Hmt-1 Hmt-1
# 16
#
# hog
# 17
#
# CG11664
# 17
#
# uri
# 17
#
# otk
# 17
#
# Ubp64E Ubp64E
# 10
#
# Irp-1B
# 17
#
# CG8281
# 17
#
# CG9541
# 17
#
# CG6845
# 17
#
# CR44339
# 17
#
# CG1532
# 17
#
# mRpL10
# 17
#
# CG6543 CG6543
# 15
#
# CG30495
# 17
#
# CG15153
# 16
#
# CG33331
# 17
#
# CG31546 CG31546
# 13
#
# CG2217
# 17
#
# CG11334
# 17
#
# Mur2B
# 16
#
# CG10405
# 17
#
# axo
# 17
#
# CG31949
# 16
#
# CG34113
# 17
#
# CR45672
# 17
#
# CG9555
# 16
#
# CR44457
# 17
#
# Hr96
# 17
#
# ATPsyn-Cf6
# 17
#
# CG16798
# 17
#
# CG5569
# 16
#
# CR44112
# 17
#
# Inos
# 17
#
# Edem2 Edem2
# 13
#
# CG5414 CG5414
# 16
#
# kkv
# 17
#
# sut3
# 17
#
# CG4365
# 16
#
# CG6067 CG6067
# 16
#
# CG42752
# 16
#
# tRNA:CR30257
# 17
#
# CG11298
# 16
#
# scpr-A
# 17
#
# Ts
# 17
#
# CG42237
# 16
#
# CG11241 CG11241
# 12
#
# CR44323
# 17
#
# Tsf3
# 17
#
# Cep135
# 16
#
# CG31751
# 17
#
# Aats-trp
# 17
#
# CG18130
# 17
#
# CG42837 CG42837
# 12
#
# snoRNA:Me28S-C2645b
# 17
#
# RunxB
# 17
#
# csw
# 17
#
# Rgk1
# 17

# %%
positions.close()
